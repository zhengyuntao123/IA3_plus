# %%
# !pip install evaluate
# 参考1：https://github.com/EleutherAI/lm-evaluation-harness?tab=readme-ov-file#overview
# 参考2：https://github.com/meta-llama/llama-recipes/tree/main/tools/benchmarks/llm_eval_harness
# 参考3：https://github.com/meta-llama/llama-recipes/tree/main/tools/benchmarks/llm_eval_harness/meta_eval
# 参考4：https://huggingface.co/datasets/meta-llama/Llama-3.2-1B-evals

# %%
import os
# os.environ["HF_TOKEN"] = "替换成你自己的hugging face密钥"

# %% [markdown]
# # 评估MMLU上LoRA微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_LoRA_mmlu" \
    --tasks mmlu \
    --device cuda:0 \
    --batch_size 16
# Out:
# 2024-11-24 14:24:35.989723: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-24 14:24:35.989763: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-24 14:24:35.990226: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-24 14:24:35.993378: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # 评估MMLU上IA3微调

# %%
# from transformers import AutoModel, AutoTokenizer

# model = AutoModel.from_pretrained("model/1B_finetuned_llama3.2_IA3")

# tokenizer = AutoTokenizer.from_pretrained("model/1B_finetuned_llama3.2_IA3")

# model.push_to_hub("1B_finetuned_llama3.2_IA3", use_auth_token=os.getenv("HF_TOKEN"))
# tokenizer.push_to_hub("1B_finetuned_llama3.2_IA3", use_auth_token=os.getenv("HF_TOKEN"))

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_IA3_mmlu" \
    --tasks mmlu \
    --device cuda:0 \
    --batch_size 16
# Out:
# 2024-11-24 14:07:30.742719: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-24 14:07:30.742757: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-24 14:07:30.743214: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-24 14:07:30.746177: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # 评估HellaSwag上LoRA微调

# %%
# !lm_eval --model hf \
#     --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_LoRA_hellaswag" \
#     --tasks hellaswag \
#     --device cuda:0 \
#     --batch_size 16

# %% [markdown]
# # 评估HellaSwag上IA3微调

# %%
# !lm_eval --model hf \
#     --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_IA3_hellaswag" \
#     --tasks hellaswag \
#     --device cuda:0 \
#     --batch_size 16

# %% [markdown]
# # 评估arc_challenge上LoRA微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_LoRA_arc_challenge" \
    --tasks arc_challenge \
    --device cuda:0 \
    --batch_size 16
# Out:
# 2024-11-24 14:09:47.054597: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-24 14:09:47.054640: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-24 14:09:47.055115: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-24 14:09:47.058145: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# # 评估arc_challenge上IA3微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_IA3_arc_challenge" \
    --tasks arc_challenge \
    --device cuda:0 \
    --batch_size 16
# Out:
# 2024-11-24 14:10:13.074504: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-24 14:10:13.074542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-24 14:10:13.075009: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-24 14:10:13.078038: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## 评估mmlu上ours wo skip-connection微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_ours_arc_challenge" \
    --tasks mmlu \
    --device cuda:0 \
    --batch_size 16 \
    --trust_remote_code
# Out:
# 2024-12-07 21:21:01.680847: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-07 21:21:01.680891: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-07 21:21:01.681397: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 21:21:01.684684: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## 评估arc_challenge上ours wo skip-connection微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_ours_arc_challenge" \
    --tasks arc_challenge \
    --device cuda:0 \
    --batch_size 16 \
    --trust_remote_code
# Out:
# 2024-12-07 21:18:21.657181: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-07 21:18:21.657217: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-07 21:18:21.657705: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 21:18:21.660829: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## 评估mmlu上ours+skip-connection微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_ours_residual_mmlu" \
    --tasks mmlu \
    --device cuda:0 \
    --batch_size 16 \
    --trust_remote_code
# Out:
# 2024-12-05 21:20:46.516669: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-05 21:20:46.516708: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-05 21:20:46.517196: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-05 21:20:46.520348: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## 评估arc_challenge上ours+skip-connection微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_ours_residual_arc_challenge" \
    --tasks arc_challenge \
    --device cuda:0 \
    --batch_size 16 \
    --trust_remote_code
# Out:
# 2024-12-07 21:17:22.510266: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-07 21:17:22.510308: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-07 21:17:22.512744: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 21:17:22.520772: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## 评估MMLU上ours wo o_proj微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_ours_residual_wo_o_proj_mmlu" \
    --tasks mmlu \
    --device cuda:0 \
    --batch_size 16 \
    --trust_remote_code
# Out:
# 2024-12-07 20:19:17.983867: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-07 20:19:17.983917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-07 20:19:17.987906: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-07 20:19:18.010047: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# ## 评估arc_challenge上ours wo o_proj微调

# %%
# !lm_eval --model hf \
    --model_args "pretrained=yuntaozh/1B_finetuned_llama3.2_ours_residual_wo_o_proj_arc_challenge" \
    --tasks arc_challenge \
    --device cuda:0 \
    --batch_size 16 \
    --trust_remote_code
# Out:
# 2024-12-06 21:16:06.615470: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-06 21:16:06.615505: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-06 21:16:06.615993: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-06 21:16:06.619334: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
